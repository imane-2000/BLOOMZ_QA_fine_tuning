# %%
# !pip install datasets
# !pip install transformers
# !pip install accelerate==0.20.3

# %%
from datasets import load_dataset

# %%
CSqa=load_dataset("commonsense_qa")

# %%
CSqa
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'question', 'question_concept', 'choices', 'answerKey'],
#         num_rows: 9741
#     })
#     validation: Dataset({
#         features: ['id', 'question', 'question_concept', 'choices', 'answerKey'],
#         num_rows: 1221
#     })
#     test: Dataset({
#         features: ['id', 'question', 'question_concept', 'choices', 'answerKey'],
#         num_rows: 1140
#     })
# })

# %%
import pandas as pd

common=pd.DataFrame(CSqa['validation'])

# %%
common
# Out:
#                                     id  \
# 0     1afa02df02c908a558b4036e80242fac
# 1     a7ab086045575bb497933726e4e6ad28
# 2     b8c0a4703079cf661d7261a60a1bcbff
# 3     e68fb2448fd74e402aae9982aa76e527
# 4     2435de612dd69f2012b9e40d6af4ce38
# ...                                ...
# 1216  6c84e79d0595efd99596faa07c4961d0
# 1217  88f1fe6cfbcb1a25f25454341c789463
# 1218  5074bcaf0f700c9f3c8c563067af156a
# 1219  6a253e076cd2af00e17d9950d70daf47
# 1220  5af7c7860e3be61d4cfd814cc109f9d9
#
#                                                question question_concept  \
# 0     A revolving door is convenient for two directi...   revolving door
# 1                     What do people aim to do at work?           people
# 2     Where would you find magazines along side many...        magazines
# 3            Where are  you likely to find a hamburger?        hamburger
# 4     James was looking for a good place to buy farm...         farmland
# ...

# %%
def format_choices(choices):
    result = "\n".join(f"{label} {text}" for label, text in zip(choices['label'], choices['text']))
    return result
common['formatted_choices'] = common['choices'].apply(format_choices)

# %%
common
# Out:
#                                     id  \
# 0     1afa02df02c908a558b4036e80242fac
# 1     a7ab086045575bb497933726e4e6ad28
# 2     b8c0a4703079cf661d7261a60a1bcbff
# 3     e68fb2448fd74e402aae9982aa76e527
# 4     2435de612dd69f2012b9e40d6af4ce38
# ...                                ...
# 1216  6c84e79d0595efd99596faa07c4961d0
# 1217  88f1fe6cfbcb1a25f25454341c789463
# 1218  5074bcaf0f700c9f3c8c563067af156a
# 1219  6a253e076cd2af00e17d9950d70daf47
# 1220  5af7c7860e3be61d4cfd814cc109f9d9
#
#                                                question question_concept  \
# 0     A revolving door is convenient for two directi...   revolving door
# 1                     What do people aim to do at work?           people
# 2     Where would you find magazines along side many...        magazines
# 3            Where are  you likely to find a hamburger?        hamburger
# 4     James was looking for a good place to buy farm...         farmland
# ...

# %%
def buildprompt(data):
    prompt = {}
    prompt['text'] = "answer the following question by specifying the answer key: \n"+ data['question'] +"\n" + data['formatted_choices']+ "\nAnswer: " + data['answerKey']
    return prompt

common['prompt'] = common.apply(buildprompt, axis=1)

# %%
common['prompt']
# Out:
# 0       {'text': 'answer the following question by spe...
# 1       {'text': 'answer the following question by spe...
# 2       {'text': 'answer the following question by spe...
# 3       {'text': 'answer the following question by spe...
# 4       {'text': 'answer the following question by spe...
#                               ...
# 1216    {'text': 'answer the following question by spe...
# 1217    {'text': 'answer the following question by spe...
# 1218    {'text': 'answer the following question by spe...
# 1219    {'text': 'answer the following question by spe...
# 1220    {'text': 'answer the following question by spe...
# Name: prompt, Length: 1221, dtype: object

# %%
import json
result = common['prompt'].to_list()
with open('prompts.json', 'w') as outfile:
    json.dump(result, outfile, ensure_ascii=False)

# %%
dataset = load_dataset("json", data_files="prompts.json")
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
from transformers import BloomTokenizerFast, BloomForCausalLM, TrainingArguments, Trainer
import torch

checkpoint = "bigscience/bloomz-560m"

tokenizer = BloomTokenizerFast.from_pretrained(checkpoint)
model = BloomForCausalLM.from_pretrained(checkpoint).to("cuda")

# %%
def prepare_train_data(data):
    # prompt + completion
    text_input = data['text']
    # tokenize the input (prompt + completion) text
    tokenized_input = tokenizer(
    text_input,
    return_tensors='pt',
    padding='max_length',  # Pad to the maximum length
    max_length=93  # Set the maximum length
)
    # generative models: labels are the same as the input
    tokenized_input['labels'] = tokenized_input['input_ids']
    return tokenized_input

train_dataset = dataset['train'].map(prepare_train_data,
                                     batched=True,
                                     remove_columns=["text"])
# Out:
# Map:   0%|          | 0/1221 [00:00<?, ? examples/s]

# %%
training_arguments = TrainingArguments(
    'FT-bloom-560m',
    learning_rate=2e-5,
    per_device_train_batch_size=2,
    num_train_epochs=4,
    weight_decay=0.01,
    fp16=True,
    optim="adafactor",
    gradient_accumulation_steps=4,
    gradient_checkpointing=True
)

# %%
trainer = Trainer(
    model = model,
    args = training_arguments,
    train_dataset = train_dataset
)

# %%
trainer.train()
# Out:
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='608' max='608' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [608/608 10:30, Epoch 3/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>2.056300</td>
#     </tr>
#   </tbody>
# </table><p>
# ...

# %%
trainer.save_model()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model = BloomForCausalLM.from_pretrained("/content/drive/MyDrive/FT-bloom-560m").to('cuda')

# %%
import pandas as pd

# %%
commontest=pd.read_csv('/content/Commontest-processed.csv')

# %%
commontest
# Out:
#      Unnamed: 0                                             prompt answerKey  \
# 0             0  answer the following question by specifying th...         A
# 1             1  answer the following question by specifying th...         B
# 2             2  answer the following question by specifying th...         B
# 3             3  answer the following question by specifying th...         D
# 4             4  answer the following question by specifying th...         C
# ..          ...                                                ...       ...
# 120         120  answer the following question by specifying th...         E
# 121         121  answer the following question by specifying th...         A
# 122         122  answer the following question by specifying th...         D
# 123         123  answer the following question by specifying th...         C
# 124         124  answer the following question by specifying th...         E
#
#     BloomZ-560m BloomZ-3b
# ...

# %%
results = []
for i, P in enumerate(commontest["prompt"]):
    prompt = P
    inputs = tokenizer(prompt, return_tensors="pt")
    inputs = {k: v.to('cuda:0') for k, v in inputs.items()}  # Move inputs to cuda:0

    # Ensure the model is on the same device (cuda:0)
    model.to('cuda:0')

    result = (tokenizer.decode(model.generate(inputs["input_ids"],
                       max_length=len(prompt) + 1,
                       do_sample=True,
                       top_k=50,
                       top_p=0.9
                      )[0]))
    results.append(result[len(prompt)+1])

# %%
len(results)
# Out:
# 125

# %%
commontest['BloomZ-ft']=results

# %%
commontest
# Out:
#      Unnamed: 0                                             prompt answerKey  \
# 0             0  answer the following question by specifying th...         A
# 1             1  answer the following question by specifying th...         B
# 2             2  answer the following question by specifying th...         B
# 3             3  answer the following question by specifying th...         D
# 4             4  answer the following question by specifying th...         C
# ..          ...                                                ...       ...
# 120         120  answer the following question by specifying th...         E
# 121         121  answer the following question by specifying th...         A
# 122         122  answer the following question by specifying th...         D
# 123         123  answer the following question by specifying th...         C
# 124         124  answer the following question by specifying th...         E
#
#     BloomZ-560m BloomZ-3b BloomZ-ft
# ...

# %%
def replace_values(value):
    if value not in ['A', 'B', 'C', 'D', 'E']:
        return 'M'
    else:
        return value

# %%
commontest['BloomZ-ft'] = commontest['BloomZ-ft'].apply(replace_values)

# %%
commontest['BloomZ-3b'] = commontest['BloomZ-3b'].apply(replace_values)
commontest['BloomZ-560m'] = commontest['BloomZ-560m'].apply(replace_values)

# %%
commontest
# Out:
#      Unnamed: 0                                             prompt answerKey  \
# 0             0  answer the following question by specifying th...         A
# 1             1  answer the following question by specifying th...         B
# 2             2  answer the following question by specifying th...         B
# 3             3  answer the following question by specifying th...         D
# 4             4  answer the following question by specifying th...         C
# ..          ...                                                ...       ...
# 120         120  answer the following question by specifying th...         E
# 121         121  answer the following question by specifying th...         A
# 122         122  answer the following question by specifying th...         D
# 123         123  answer the following question by specifying th...         C
# 124         124  answer the following question by specifying th...         E
#
#     BloomZ-560m BloomZ-3b BloomZ-ft
# ...

# %%
commontest.to_csv('results.csv')

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
def generate_evaluation_report(df, label_column, prediction_column, labels):
    # Calculate accuracy
    accuracy = accuracy_score(df[label_column], df[prediction_column])

    # Calculate confusion matrix
    conf_matrix = confusion_matrix(df[label_column], df[prediction_column], labels=labels)
    confusion_df = pd.DataFrame(conf_matrix, columns=labels, index=labels)

    # Generate a classification report
    class_report = classification_report(df[label_column], df[prediction_column], labels=labels, output_dict=True)

    evaluation_report = {
        'Accuracy': accuracy,
        'Confusion Matrix': confusion_df,
        'Classification Report': class_report
    }

    return evaluation_report

# %%
def print_evaluation_report(report):
    print(f'Accuracy: {report["Accuracy"]:.2f}\n')
    print("Confusion Matrix:")
    print(report['Confusion Matrix'])
    print("\nClassification Report:")
    for label, metrics in report['Classification Report'].items():
        if label not in ['accuracy', 'macro avg', 'weighted avg']:
            print(f"Label {label} - Precision: {metrics['precision']:.2f}, Recall: {metrics['recall']:.2f}, F1-Score: {metrics['f1-score']:.2f}")

# %%
labels = ['A', 'B', 'C', 'D', 'E', 'M']

# %%
report_ft = generate_evaluation_report(commontest, 'answerKey', 'BloomZ-ft', labels)
report_560m=generate_evaluation_report(commontest, 'answerKey', 'BloomZ-560m', labels)
report_3b=generate_evaluation_report(commontest, 'answerKey', 'BloomZ-3b', labels)

# %%
print("Evaluation Report for the fine-tuned model:")
print_evaluation_report(report_ft)
# Out:
# Evaluation Report for the fine-tuned model:
# Accuracy: 0.23
#
# Confusion Matrix:
#    A   B  C  D  E  M
# A  6   5  6  4  1  3
# B  7   6  4  6  0  2
# C  3   5  9  4  1  3
# D  5   3  4  7  2  4
# E  3  10  7  3  1  1
# M  0   0  0  0  0  0
#
# Classification Report:
# Label A - Precision: 0.25, Recall: 0.24, F1-Score: 0.24
# Label B - Precision: 0.21, Recall: 0.24, F1-Score: 0.22
# Label C - Precision: 0.30, Recall: 0.36, F1-Score: 0.33
# Label D - Precision: 0.29, Recall: 0.28, F1-Score: 0.29
# Label E - Precision: 0.20, Recall: 0.04, F1-Score: 0.07
# Label M - Precision: 0.00, Recall: 0.00, F1-Score: 0.00

# %%
print("Evaluation Report for BLOOMZ-560m model:")
print_evaluation_report(report_560m)
# Out:
# Evaluation Report for BLOOMZ-560m model:
# Accuracy: 0.11
#
# Confusion Matrix:
#    A  B  C  D  E   M
# A  3  4  1  4  1  12
# B  3  5  2  2  1  12
# C  6  3  2  0  4  10
# D  0  4  0  4  2  15
# E  4  2  3  4  0  12
# M  0  0  0  0  0   0
#
# Classification Report:
# Label A - Precision: 0.19, Recall: 0.12, F1-Score: 0.15
# Label B - Precision: 0.28, Recall: 0.20, F1-Score: 0.23
# Label C - Precision: 0.25, Recall: 0.08, F1-Score: 0.12
# Label D - Precision: 0.29, Recall: 0.16, F1-Score: 0.21
# Label E - Precision: 0.00, Recall: 0.00, F1-Score: 0.00
# Label M - Precision: 0.00, Recall: 0.00, F1-Score: 0.00

# %%
print("Evaluation Report for BLOOMZ-3b model:")
print_evaluation_report(report_3b)
# Out:
# Evaluation Report for BLOOMZ-3b model:
# Accuracy: 0.57
#
# Confusion Matrix:
#    A   B   C   D   E  M
# A  8   5   4   4   0  4
# B  1  15   1   4   1  3
# C  1   3  16   2   2  1
# D  2   1   1  20   1  0
# E  1   4   1   3  12  4
# M  0   0   0   0   0  0
#
# Classification Report:
# Label A - Precision: 0.62, Recall: 0.32, F1-Score: 0.42
# Label B - Precision: 0.54, Recall: 0.60, F1-Score: 0.57
# Label C - Precision: 0.70, Recall: 0.64, F1-Score: 0.67
# Label D - Precision: 0.61, Recall: 0.80, F1-Score: 0.69
# Label E - Precision: 0.75, Recall: 0.48, F1-Score: 0.59
# Label M - Precision: 0.00, Recall: 0.00, F1-Score: 0.00
